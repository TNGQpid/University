# %%
import gymnasium as gym
import random
import numpy as np
import time
from collections import deque
import pickle


from collections import defaultdict

# %%
EPISODES =  30000
LEARNING_RATE = .1
DISCOUNT_FACTOR = .99
EPSILON = 1
EPSILON_DECAY = .999


def default_Q_value():
    return 0

# %%
env_name = "CliffWalking-v0"
env = gym.envs.make(env_name)
env.reset(seed=1)

# You will need to update the Q_table in your iteration
Q_table = defaultdict(default_Q_value) # starts with a pessimistic estimate of zero reward for each state.
episode_reward_record = deque(maxlen=100)

# %%
for i in range(EPISODES):
    episode_reward = 0
    done = False
    obs = env.reset()[0]

    ##########################################################
    # YOU DO NOT NEED TO CHANGE ANYTHING ABOVE THIS LINE
    # TODO: Replace the following with Q-Learning

    while (not done):

        if random.uniform(0,1) < EPSILON:
            action = env.action_space.sample()
        else:
            prediction = np.array([Q_table[(obs,i)] for i in range(env.action_space.n)])
            action = np.argmax(prediction)
                
        next_obs,reward,terminated,truncated,info = env.step(action)
        episode_reward += reward

        done = terminated or truncated

        if done:
            Q_table[(obs, action)] = Q_table[(obs, action)] + LEARNING_RATE * (reward - Q_table[(obs,action)])
        else:
            prediction = np.array([Q_table[(next_obs,i)] for i in range(env.action_space.n)])
            expect_reward = np.max(prediction)
            Q_table[(obs, action)] = Q_table[(obs, action)] + \
                LEARNING_RATE * (reward + DISCOUNT_FACTOR * expect_reward - Q_table[(obs, action)])
            
        obs = next_obs
    EPSILON = EPSILON * EPSILON_DECAY
    # END of TODO
    # YOU DO NOT NEED TO CHANGE ANYTHING BELOW THIS LINE
    ##########################################################

    # record the reward for this episode
    episode_reward_record.append(episode_reward) 
     
    if i % 100 == 0 and i > 0:
        print("LAST 100 EPISODE AVERAGE REWARD: " + str(sum(list(episode_reward_record))/100))
        print("EPSILON: " + str(EPSILON) )
    
    
#### DO NOT MODIFY ######
model_file = open(f'Q_TABLE_QLearning.pkl' ,'wb')
pickle.dump([Q_table,EPSILON],model_file)
model_file.close()
#########################
# Out:
# LAST 100 EPISODE AVERAGE REWARD: -533.89
# EPSILON: 0.4076082248025454
# LAST 100 EPISODE AVERAGE REWARD: -333.49
# EPSILON: 0.3688007209003024
# LAST 100 EPISODE AVERAGE REWARD: -300.0
# EPSILON: 0.33368799612046873
# LAST 100 EPISODE AVERAGE REWARD: -270.79
# EPSILON: 0.30191827847590974
# LAST 100 EPISODE AVERAGE REWARD: -193.47
# EPSILON: 0.27317328743509334
# LAST 100 EPISODE AVERAGE REWARD: -136.15
# EPSILON: 0.24716504527250852
# LAST 100 EPISODE AVERAGE REWARD: -171.03
# EPSILON: 0.22363299200356998
# LAST 100 EPISODE AVERAGE REWARD: -133.75
# EPSILON: 0.20234137500037297
# LAST 100 EPISODE AVERAGE REWARD: -95.5
# EPSILON: 0.18307688713652753
# LAST 100 EPISODE AVERAGE REWARD: -134.68
# EPSILON: 0.16564652979915298
# LAST 100 EPISODE AVERAGE REWARD: -92.37
# EPSILON: 0.1498756793589105
# LAST 100 EPISODE AVERAGE REWARD: -80.81
# EPSILON: 0.13560633772727437
# LAST 100 EPISODE AVERAGE REWARD: -61.37
# EPSILON: 0.12269554947448735
# LAST 100 EPISODE AVERAGE REWARD: -66.67
# EPSILON: 0.11101396965031775
# LAST 100 EPISODE AVERAGE REWARD: -64.44
# EPSILON: 0.1004445679595271
# LAST 100 EPISODE AVERAGE REWARD: -47.15
# EPSILON: 0.0908814563100094
# LAST 100 EPISODE AVERAGE REWARD: -48.44
# EPSILON: 0.08222882798755414
# LAST 100 EPISODE AVERAGE REWARD: -40.57
# EPSILON: 0.0743999978295029
# LAST 100 EPISODE AVERAGE REWARD: -37.61
# EPSILON: 0.06731653378141127
# LAST 100 EPISODE AVERAGE REWARD: -39.21
# EPSILON: 0.06090747113633568
# LAST 100 EPISODE AVERAGE REWARD: -30.93
# EPSILON: 0.05510860158471143
# LAST 100 EPISODE AVERAGE REWARD: -32.5
# EPSILON: 0.04986182995226502
# LAST 100 EPISODE AVERAGE REWARD: -29.58
# EPSILON: 0.04511459218152853
# LAST 100 EPISODE AVERAGE REWARD: -26.59
# EPSILON: 0.04081932872608455
# LAST 100 EPISODE AVERAGE REWARD: -25.4
# EPSILON: 0.03693300808181433
# LAST 100 EPISODE AVERAGE REWARD: -24.22
# EPSILON: 0.033416695681712745
# LAST 100 EPISODE AVERAGE REWARD: -25.49
# EPSILON: 0.03023516383530229
# LAST 100 EPISODE AVERAGE REWARD: -28.24
# EPSILON: 0.027356538804877914
# LAST 100 EPISODE AVERAGE REWARD: -20.69
# EPSILON: 0.024751981482865
# LAST 100 EPISODE AVERAGE REWARD: -17.44
# EPSILON: 0.022395398471200194
# LAST 100 EPISODE AVERAGE REWARD: -22.91
# EPSILON: 0.020263180668224277
# LAST 100 EPISODE AVERAGE REWARD: -23.8
# EPSILON: 0.018333966744155647
# LAST 100 EPISODE AVERAGE REWARD: -16.54
# EPSILON: 0.016588429135555912
# LAST 100 EPISODE AVERAGE REWARD: -15.31
# EPSILON: 0.015009080414803248
# LAST 100 EPISODE AVERAGE REWARD: -16.39
# EPSILON: 0.013580098094712154
# LAST 100 EPISODE AVERAGE REWARD: -20.71
# EPSILON: 0.012287166113129402
# LAST 100 EPISODE AVERAGE REWARD: -13.17
# EPSILON: 0.01111733140944116
# LAST 100 EPISODE AVERAGE REWARD: -15.21
# EPSILON: 0.010058874156122952
# LAST 100 EPISODE AVERAGE REWARD: -17.28
# EPSILON: 0.009101190345265084
# LAST 100 EPISODE AVERAGE REWARD: -14.25
# EPSILON: 0.008234685553782952
# LAST 100 EPISODE AVERAGE REWARD: -16.23
# EPSILON: 0.007450678823013516
# LAST 100 EPISODE AVERAGE REWARD: -13.04
# EPSILON: 0.006741315689729041
# LAST 100 EPISODE AVERAGE REWARD: -14.04
# EPSILON: 0.006099489497281272
# LAST 100 EPISODE AVERAGE REWARD: -16.26
# EPSILON: 0.005518770198542642
# LAST 100 EPISODE AVERAGE REWARD: -14.04
# EPSILON: 0.004993339937366545
# LAST 100 EPISODE AVERAGE REWARD: -13.02
# EPSILON: 0
-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.5504521761167866e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.117213394766961e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.725222347576523e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.3705519263397316e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.0496489143911736e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.7592983891949806e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.4965915140871243e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.258896396496754e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0438317206937163e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8492428909055736e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6731804457972167e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.5138805280615353e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.3697472134584324e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.2393365222680746e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.121341952979369e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0145813932848832e-08
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.179852772518474e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.305858700234727e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.515075727008457e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.799581502762098e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.152207947358783e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.566469438180777e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.036497834814426e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.5569836898952895e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.123123057142506e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.730569363686009e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.3753898645260875e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.05402624287041e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.7632589616283325e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.5001750089228953e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.2621387144833843e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0467653445464658e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.851897210730126e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6755820535303994e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.516053483878968e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.3717132868180705e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.2411154100045253e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.1229514766339059e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0160376776481021e-09
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.193029119076526e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.317780555128099e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.525862527695008e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.809341315315768e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.161038549114642e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.574459297303767e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.043726996605447e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.5635245787140205e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.129041201980843e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.735924054661217e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.3802347468706755e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.0584098543694833e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.7672252188886906e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.5037636473455005e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.2653856863469853e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0497031791905521e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8545553404456158e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6779871084229845e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.5182295586591552e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.373682182190716e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.2428968510761835e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.124563310526087e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0174960522961992e-10
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.206224378368011e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.329719522114165e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.536664811268657e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.819115136664107e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.16988182591791e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.582460624710117e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.050966534809202e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.570074856029508e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.1349678414573126e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.741286431518298e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.385086583340828e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.0627997579067564e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.7711971691358016e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.5073574367378125e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.2686373187675304e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.052645230669962e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8572172855205893e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6803956154228683e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.5204087568789223e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.3756539036269658e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.2446808491479976e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.1261774579719314e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.018956520229482e-11
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.21943857753947e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.34167562575489e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.547482599952859e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.828902986914703e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.178737795961773e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.590473436860879e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.058216464319512e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.576634535317566e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.140902987764733e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.7466565052892236e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.3899453839181822e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.06719596251354e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.7751748205411255e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.510956384493307e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.271893618434575e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.055591505037351e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8598830514314442e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6828075794850536e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.5225910830215043e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.377628455183215e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.246467407890164e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.1277939222922005e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0204190844525526e-12
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.23267174377631e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.353648890647442e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.55831591600295e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.838704886204028e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.187606477465558e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.598497750240755e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.065476800051604e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.583203630073376e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.1468466531134337e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.7520342870218013e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.3948111585987105e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.0715984772341053e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.779158181287846e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.514560498016062e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.275154592047272e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0585420083540668e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8625526436624414e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.685223005571655e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.5247765415765952e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.379605840921702e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.2482565309781605e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.12941270681244e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0218837479743338e-13
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.245923904303019e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.365639341424292e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.569164781706192e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.848520854697411e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.196487888674688e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.606533581358068e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.072747556942079e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.5897821538114436e-14

# %%
for i in range(EPISODES):
    episode_reward = 0
    done = False
    obs = env.reset()[0]

    ##########################################################
    # YOU DO NOT NEED TO CHANGE ANYTHING ABOVE THIS LINE
    # TODO: Replace the following with Q-Learning

    while (not done):

        if random.uniform(0,1) < EPSILON:
            action = env.action_space.sample()
        else:
            prediction = []
            for a in range(env.action_space.n):
                prediction.append(Q_table[(obs,a)])
            prediction = np.array(prediction)
            action = np.argmax(prediction)
                
        next_obs,reward,terminated,truncated,info = env.step(action)
        episode_reward += reward

        done = terminated or truncated

        if done:
            Q_table[(obs, action)] = Q_table[(obs, action)] + LEARNING_RATE * (reward - Q_table[(obs,action)])
        else:
            predictio = []
            for a in range(env.action_space.n):
                predictio.append(Q_table[(next_obs,a)])
            predictio = np.array(predictio)
            expected_reward = np.max(predictio)
            Q_table[(obs, action)] = Q_table[(obs, action)] + \
                LEARNING_RATE * (reward + DISCOUNT_FACTOR * expected_reward - Q_table[(obs, action)])
            
        obs = next_obs
    EPSILON = EPSILON * EPSILON_DECAY
    # END of TODO
    # YOU DO NOT NEED TO CHANGE ANYTHING BELOW THIS LINE
    ##########################################################

    # record the reward for this episode
    episode_reward_record.append(episode_reward) 
     
    if i % 100 == 0 and i > 0:
        print("LAST 100 EPISODE AVERAGE REWARD: " + str(sum(list(episode_reward_record))/100))
        print("EPSILON: " + str(EPSILON) )
    
    
#### DO NOT MODIFY ######
model_file = open(f'Q_TABLE_QLearning.pkl' ,'wb')
pickle.dump([Q_table,EPSILON],model_file)
model_file.close()
#########################
# Out:
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.332226944440451e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.538933507298967e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.821167835016515e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.171739091267567e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.584141063813596e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.0524869829137344e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.5714505455345817e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.136212554518368e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.7424126381213544e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.3861055662312975e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.0637217256240966e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.7720313582863424e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.5081122045304322e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.2693202267391876e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0532631204399185e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8577763473322264e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6809014501597886e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.5208664321766215e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.3760680046422508e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.2450555244947386e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.12651646128338e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0192632477635261e-14
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.222213824180526e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.344186647122025e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.549754552367075e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.830958631617704e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.180597727146308e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.592156287990817e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.059739094806643e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.5780121994252786e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.1421494874307516e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.747784328398419e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.3909658294107173e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.0681192535817417e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.7760102070491335e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.5117122356455564e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.272577506621517e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0562102816984012e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8604429156951787e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6833141402743291e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.523049415245677e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.3780431505804149e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.246842621028994e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.1281334121937082e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0207262522494598e-15
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.235450973881183e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.356163516221357e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.560591129475158e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.840763481486693e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.189469078311395e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.600183016859279e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.067001616053832e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.584583271617981e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.1480949419488247e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.753163728957391e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.3958330687926536e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.0725230935526407e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.779994766871949e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.5153174340829474e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.275839461856456e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0591616731792112e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8631133115300763e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6857302934554297e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.5252355316701612e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.380021131553964e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.2486322826810011e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.129752684002434e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0221913566660379e-16
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.2487071235894e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.368157576378306e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.571443260917176e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.850582404794875e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.198353163013752e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.608221266932258e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.0742745615964003e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.591163775631284e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.154048930304112e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.758550850865263e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.4007072943904395e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.076933254596776e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.783985045952189e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.51892780725954e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.2791060991547877e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0621173009542094e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8657875403306846e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6881499146738072e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.527424785947539e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.3820019516321709e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.2504245131326081e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.1313742800408668e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0236585640274032e-17
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.2619823005769e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.380168852268147e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.582310969019131e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.86041542174265e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.207249999530531e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.6162710547467976e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.081557946396926e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.597753725003206e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.160011464745705e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.763945705204912e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.4055885162317723e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.0813497457871364e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.787981052499025e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.5225433626029296e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.2823774252369396e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0650771711039896e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.8684656075986823e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.6905730089073326e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.5296171825817497e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.3839856148901643e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.2522193160709583e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.1329982036451026e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1.0251278773520284e-18
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 9.275276532154606e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 8.392197368601553e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 7.593194276139017e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.870262552559344e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 6.216159606165081e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.624332396863611e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 5.088851785439417e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.604353133291161e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 4.1659825575402477e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.7693483030751034e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.4104767443587386e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 3.085772576209715e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.7919827947333906e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.52616410755136e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.285653446832983e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 2.0680412897178638e-19
# LAST 100 EPISODE AVERAGE REWARD: -13.0
# EPSILON: 1